# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
pd.DataFrame.to_csv?

# %%
from sklearn.linear_model import LogisticRegression

# %%
data = pd.read_csv('out/univariable_rf.csv')

# %%
fig, ax = plt.subplots(figsize=(6, 16))

bars = ax.barh(data.feature.values[::-1], data.balanced_accuracy.values[::-1], 
               color='#22aed1')

ax.set_ylim(-1, len(data))
ax.set_xticks(np.arange(0, 1.1, 0.1))
ax.tick_params(axis='y', rotation=0, labelsize=7)
ax.vlines(0.5, -2, len(data)+1, color='gray', linestyle='--')

for bar in bars:
    if bar.get_width() > 0.75:
        bar.set_color('#750000')
        
ax.grid(axis='x', zorder=-10, alpha=0.2)

# %%
model = Logi
