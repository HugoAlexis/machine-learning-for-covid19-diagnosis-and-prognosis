# %% [markdown]
# # Seleccion de caracteristicas

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import LeaveOneOut, GridSearchCV

from sklearn.preprocessing import LabelBinarizer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.metrics import roc_auc_score

from plots import *
from metrics import *
from evaluation import *

data = pd.read_csv('data_preprocess/tran.csv')

# %%
with open('out/features_boruta.txt', 'r') as f:
    features_boruta = f.readlines()
    features_boruta = [feature.strip('\n') for feature in features_boruta]
with open('out/features_forward.txt', 'r') as f:
    features_forward = f.readlines()
    features_forward = [feature.strip('\n') for feature in features_forward]
with open('out/features_genetic.txt', 'r') as f:
    features_genetic = f.readlines()
    features_genetic = [feature.strip('\n') for feature in features_genetic]
with open('out/features_lasso.txt', 'r') as f:
    features_lasso = f.readlines()
    features_lasso = [feature.strip('\n') for feature in features_lasso]

# %%
def evaluate_model(features, model, )

# %%
all_features_selected = list(set(features_boruta + 
                                 features_forward + 
                                 features_genetic + 
                                 features_lasso))

all_features_selected.sort(key=lambda x: -(features_boruta + 
                                 features_forward + 
                                 features_genetic + 
                                 features_lasso).count(x))

# %%
fig, ax = plt.subplots(figsize=(15, 4))

ax.scatter(all_features_selected, [0]*len(all_features_selected), s=0)
ax.scatter(features_boruta, [4]*len(features_boruta), 
           s=350, marker='o', zorder=5)
ax.scatter(features_forward, [3]*len(features_forward), 
           s=350, marker='o', zorder=5)
ax.scatter(features_genetic, [2]*len(features_genetic), 
           s=350, marker='o', zorder=5)
ax.scatter(features_lasso, [1]*len(features_lasso), 
           s=350, marker='o', zorder=5)

ax.set(yticks=[1, 2, 3, 4], 
       yticklabels=['LASSO', 'Algoritmos\nGenéticos',
                    'Selección\nhacia\nadelante', 'Boruta'])

ax.set_ylim(0.5, 4.5)
ax.set_xlim(-1, len(all_features_selected))
ax.tick_params(labelsize=15)
ax.tick_params(axis='x', rotation=90)
ax.grid(alpha=0.3, axis='both', zorder=0)

plt.savefig('results_plots/metabolitos_seleccionados.pdf', 
            bbox_inches='tight')

# %% [markdown]
# ## Boruta

# %%
X = data[features_boruta]
y = data['Positivo']

model = model_obj(**model_params)
ytrue, ypred = predict_model_loo(model, X, y, proba=True)

mat = confusion_matrix(ytrue, ypred, r=0.5)
fig, ax = plt.subplots(figsize=(5, 5))
plot_confusion_matrix(mat, ax=ax, 
                      save_as=f'results_plots/{results_model_dir}/train_confusion_matrix_boruta.pdf')
# Out:
# 0it [00:00, ?it/s]C:\Users\hugoa\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hugoa\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
fig, ax = plt.subplots(figsize=(7, 4))
plot_kde_predictions(ytrue, ypred, ax=ax, draw_r=False, 
                     save_as=f'results_plots/{results_model_dir}/train_kdeplot_boruta.pdf')

# %%
metrics_boruta = get_metrics(*mat.ravel())
metrics_boruta['roc_auc'] = roc_auc_score(ytrue, ypred)

metrics_boruta
# Out:
# {'precision': 0.9176470588235294,
#  'recall': 0.9069767441860465,
#  'f1': 0.9122807017543859,
#  'accuracy': 0.8636363636363636,
#  'specificity': 0.7083333333333334,
#  'roc_auc': 0.9402352941176471}

# %% [markdown]
# ## Forward Selection

# %%
X = data[features_forward]
y = data['Positivo']

model = model_obj(**model_params)
ytrue, ypred = predict_model_loo(model, X, y, proba=True)

mat = confusion_matrix(ytrue, ypred, r=0.5)

fig, ax = plt.subplots(figsize=(5, 5))
plot_confusion_matrix(mat, ax=ax, 
                      save_as=f'results_plots/{results_model_dir}/train_confusion_matrix_forward.pdf')
# Out:
# 110it [00:02, 51.39it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 10
#       7 mat = confusion_matrix(ytrue, ypred, r=0.5)
#       9 fig, ax = plt.subplots(figsize=(5, 5))
# ---> 10 plot_confusion_matrix(mat, ax=ax,
#      11                       save_as=f'results_plots/{results_model_dir}/train_confusion_matrix_forward.pdf')
#
# File ~\Desktop\MCPI\TESIS_MCPI\Analisis\plots.py:25, in plot_confusion_matrix(mat, ax, title, save_as)
#      23     ax.set_title(title, fontsize=20, fontweight='bold')
#      24 if save_as:
# ---> 25     plt.savefig(save_as, bbox_inches='tight')
#      27 return ax
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:1023, in savefig(*args, **kwargs)
#    1020 @_copy_docstring_and_deprecators(Figure.savefig)
#    1021 def savefig(*args, **kwargs):
#    1022     fig = gcf()
# ...

# %%
fig, ax = plt.subplots(figsize=(7, 4))

plot_kde_predictions(ytrue, ypred, ax=ax, draw_r=False,  
                     save_as=f'results_plots/{results_model_dir}/train_kdeplot_forward.pdf')

# %%
metrics_forward = get_metrics(*mat.ravel())
metrics_forward['roc_auc'] = roc_auc_score(ytrue, ypred)

metrics_forward
# Out:
# {'precision': 0.9294117647058824,
#  'recall': 0.8977272727272727,
#  'f1': 0.9132947976878613,
#  'accuracy': 0.8636363636363636,
#  'specificity': 0.7272727272727273,
#  'roc_auc': 0.9355294117647058}

# %% [markdown]
# ## Genetic Algorithms

# %%
X = data[features_genetic]
y = data['Positivo']

model = model_obj(**model_params)
ytrue, ypred = predict_model_loo(model, X, y, proba=True)

mat = confusion_matrix(ytrue, ypred)

fig, ax = plt.subplots(figsize=(5, 5))
plot_confusion_matrix(mat, ax=ax,
                      save_as=f'results_plots/{results_model_dir}/train_confusion_matrix_genetic.pdf')
# Out:
# 0it [00:00, ?it/s]

# %%
fig, ax = plt.subplots(figsize=(7, 4))

plot_kde_predictions(ytrue, ypred, ax=ax, draw_r=False, 
                     save_as=f'results_plots/{results_model_dir}/train_kdeplot_genetic.pdf')

# %%
metrics_genetic = get_metrics(*mat.ravel())
metrics_genetic['roc_auc'] = roc_auc_score(ytrue, ypred)

metrics_genetic

# %% [markdown]
# ## LASSO

# %%
X = data[features_lasso]
y = data['Positivo']

model = model_obj(**model_params)
ytrue, ypred = predict_model_loo(model, X, y, proba=True)

mat = confusion_matrix(ytrue, ypred)

fig, ax = plt.subplots(figsize=(5, 5))
plot_confusion_matrix(mat, ax=ax, 
                      save_as=f'results_plots/{results_model_dir}/train_confusion_matrix_lasso.pdf')

# %%
fig, ax = plt.subplots(figsize=(7, 4))

plot_kde_predictions(ytrue, ypred, ax=ax, draw_r=False, 
                     save_as=f'results_plots/{results_model_dir}/train_kdeplot_lasso.pdf')

# %%
metrics_lasso = get_metrics(*mat.ravel())
metrics_lasso['roc_auc'] = roc_auc_score(ytrue, ypred)

metrics_lasso

# %%
evaluation = pd.DataFrame({
    'boruta': metrics_boruta,
    'forward': metrics_forward,
    'genetic': metrics_genetic,
    'lasso': metrics_lasso
})

evaluation.T.to_csv('out/evaluation_random_forests.csv')
